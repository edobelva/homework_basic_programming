# %% [markdown]
# # BASIC PYTHON HOMEWORK
# This document is the answer for Use Case Pre-test at Telkomsel Data Science Academy
# <br>Name    : Edo Belva F
# <br>NIK     : 92028
# <br>Dataset : Churn
# <br>Date    : Oct, 16, 2019

# %%
import pandas as pd
import statistics as st
import numpy as np

# %%
df=pd.read_csv('churn.csv')

# %%
df.head(3)
# Out:
#    state  account_length  area_code  phone_number  international_plan  \
# 0     16             128        415          2845                   0
# 1     35             107        415          2301                   0
# 2     31             137        415          1616                   0
#
#    voice_mail_plan  number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                1                     25              265.1              110
# 1                1                     26              161.6              123
# 2                0                      0              243.4              114
#
#    total_day_charge  ...  total_eve_calls  total_eve_charge  \
# 0             45.07  ...               99             16.78
# 1             27.47  ...              103             16.62
# 2             41.38  ...              110             10.30
#
#    total_night_minutes  total_night_calls  total_night_charge  \
# ...

# %%
df.describe()
# Out:
#             state  account_length    area_code  phone_number  \
# count  5000.00000      5000.00000  5000.000000   5000.000000
# mean     25.99840       100.25860   436.911400   2499.500000
# std      14.80348        39.69456    42.209182   1443.520003
# min       0.00000         1.00000   408.000000      0.000000
# 25%      13.00000        73.00000   408.000000   1249.750000
# 50%      26.00000       100.00000   415.000000   2499.500000
# 75%      39.00000       127.00000   415.000000   3749.250000
# max      50.00000       243.00000   510.000000   4999.000000
#
#        international_plan  voice_mail_plan  number_vmail_messages  \
# count         5000.000000      5000.000000            5000.000000
# mean             0.094600         0.264600               7.755200
# std              0.292691         0.441164              13.546393
# min              0.000000         0.000000               0.000000
# 25%              0.000000         0.000000               0.000000
# ...

# %%
df['xtotal_call'] = (df['total_day_calls']+df['total_eve_calls']+df['total_night_calls'])
df['xtotal_minutes'] = (df['total_day_minutes']+df['total_eve_minutes']+df['total_night_minutes'])
df['xtotal_charge']=(df['total_day_charge']+df['total_eve_charge']+df['total_night_charge'])
df.describe()
# Out:
#             state  account_length    area_code  phone_number  \
# count  5000.00000      5000.00000  5000.000000   5000.000000
# mean     25.99840       100.25860   436.911400   2499.500000
# std      14.80348        39.69456    42.209182   1443.520003
# min       0.00000         1.00000   408.000000      0.000000
# 25%      13.00000        73.00000   408.000000   1249.750000
# 50%      26.00000       100.00000   415.000000   2499.500000
# 75%      39.00000       127.00000   415.000000   3749.250000
# max      50.00000       243.00000   510.000000   4999.000000
#
#        international_plan  voice_mail_plan  number_vmail_messages  \
# count         5000.000000      5000.000000            5000.000000
# mean             0.094600         0.264600               7.755200
# std              0.292691         0.441164              13.546393
# min              0.000000         0.000000               0.000000
# 25%              0.000000         0.000000               0.000000
# ...

# %%
inactiveuser=df[(df['xtotal_call']<241.1) | (df['xtotal_minutes']<428.3) | (df['xtotal_charge']<39.9)]

# %%
cek=inactiveuser.groupby('state')

# %%
inactiveuser.shape
# Out:
# (521, 27)

# %%
inactivestate=inactiveuser['state'].value_counts()

# %%
inactivestate.sort_values(ascending=False).head(5)
# Out:
# 49    21
# 45    19
# 6     16
# 1     15
# 44    15
# Name: state, dtype: int64

# %%
inactiveuser['area_code'].value_counts().sort_values(ascending=False)
# Out:
# 415    247
# 408    137
# 510    137
# Name: area_code, dtype: int64

# %%
inactiveuser.filter(like='xtotal_').corr(method='spearman')
# Out:
#                 xtotal_call  xtotal_minutes  xtotal_charge
# xtotal_call        1.000000       -0.634946      -0.651862
# xtotal_minutes    -0.634946        1.000000       0.821461
# xtotal_charge     -0.651862        0.821461       1.000000

# %%
inactiveuser.filter(like='total_').corr(method='spearman')
# Out:
#                      total_day_minutes  total_day_calls  total_day_charge  \
# total_day_minutes             1.000000        -0.414972          1.000000
# total_day_calls              -0.414972         1.000000         -0.414972
# total_day_charge              1.000000        -0.414972          1.000000
# total_eve_minutes             0.154380        -0.312525          0.154380
# total_eve_calls              -0.400147         0.194653         -0.400147
# total_eve_charge              0.154337        -0.312470          0.154337
# total_night_minutes          -0.032291        -0.167227         -0.032291
# total_night_calls            -0.370253         0.169447         -0.370253
# total_night_charge           -0.032392        -0.167255         -0.032392
# total_intl_minutes           -0.025662        -0.025202         -0.025662
# total_intl_calls             -0.008561         0.096040         -0.008561
# total_intl_charge            -0.025662        -0.025202         -0.025662
# ...

# %%
df.filter(like='xtotal_').corr(method='spearman')
# Out:
#                 xtotal_call  xtotal_minutes  xtotal_charge
# xtotal_call        1.000000        0.016748       0.012223
# xtotal_minutes     0.016748        1.000000       0.878666
# xtotal_charge      0.012223        0.878666       1.000000

# %%
df.filter(like='total_').corr(method='spearman')
# Out:
#                      total_day_minutes  total_day_calls  total_day_charge  \
# total_day_minutes             1.000000         0.005721          1.000000
# total_day_calls               0.005721         1.000000          0.005721
# total_day_charge              1.000000         0.005721          1.000000
# total_eve_minutes            -0.011386         0.002406         -0.011386
# total_eve_calls               0.007948         0.010889          0.007948
# total_eve_charge             -0.011406         0.002404         -0.011406
# total_night_minutes           0.002965         0.002504          0.002965
# total_night_calls             0.003409        -0.004324          0.003409
# total_night_charge            0.002942         0.002484          0.002942
# total_intl_minutes           -0.022560         0.007111         -0.022560
# total_intl_calls             -0.006131         0.008951         -0.006131
# total_intl_charge            -0.022560         0.007111         -0.022560
# ...
